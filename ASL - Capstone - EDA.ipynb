# %%
import pyarrow.parquet as pq
import pandas as pd
im

# %%
print("TensorFlow v" + tf.__version__)
print("Mediapipe v" + mediapipe.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print("TensorFlow v" + tf.__version__)
#       2 print("Mediapipe v" + mediapipe.__version__)
#
# NameError: name 'tf' is not defined

# %%
columns_of_interest = ['frame', 'x_right_hand_0', 'x_right_hand_1', 'x_right_hand_2', 'x_right_hand_3', 'x_right_hand_4', 'x_right_hand_5', 'x_right_hand_6', 'x_right_hand_7', 'x_right_hand_8', 'x_right_hand_9', 'x_right_hand_10', 'x_right_hand_11', 'x_right_hand_12', 'x_right_hand_13', 'x_right_hand_14', 'x_right_hand_15', 'x_right_hand_16', 'x_right_hand_17', 'x_right_hand_18', 'x_right_hand_19', 'x_right_hand_20', 'y_right_hand_0', 'y_right_hand_1', 'y_right_hand_2', 'y_right_hand_3', 'y_right_hand_4', 'y_right_hand_5', 'y_right_hand_6', 'y_right_hand_7', 'y_right_hand_8', 'y_right_hand_9', 'y_right_hand_10', 'y_right_hand_11', 'y_right_hand_12', 'y_right_hand_13', 'y_right_hand_14', 'y_right_hand_15', 'y_right_hand_16', 'y_right_hand_17', 'y_right_hand_18', 'y_right_hand_19', 'y_right_hand_20', 'z_right_hand_0', 'z_right_hand_1', 'z_right_hand_2', 'z_right_hand_3', 'z_right_hand_4', 'z_right_hand_5', 'z_right_hand_6', 'z_right_hand_7', 'z_right_hand_8', 'z_right_hand_9', 'z_right_hand_10', 'z_right_hand_11', 'z_right_hand_12', 'z_right_hand_13', 'z_right_hand_14', 'z_right_hand_15', 'z_right_hand_16', 'z_right_hand_17', 'z_right_hand_18', 'z_right_hand_19', 'z_right_hand_20', 'x_left_hand_0', 'x_left_hand_1', 'x_left_hand_2', 'x_left_hand_3', 'x_left_hand_4', 'x_left_hand_5', 'x_left_hand_6', 'x_left_hand_7', 'x_left_hand_8', 'x_left_hand_9', 'x_left_hand_10', 'x_left_hand_11', 'x_left_hand_12', 'x_left_hand_13', 'x_left_hand_14', 'x_left_hand_15', 'x_left_hand_16', 'x_left_hand_17', 'x_left_hand_18', 'x_left_hand_19', 'x_left_hand_20', 'y_left_hand_0', 'y_left_hand_1', 'y_left_hand_2', 'y_left_hand_3', 'y_left_hand_4', 'y_left_hand_5', 'y_left_hand_6', 'y_left_hand_7', 'y_left_hand_8', 'y_left_hand_9', 'y_left_hand_10', 'y_left_hand_11', 'y_left_hand_12', 'y_left_hand_13', 'y_left_hand_14', 'y_left_hand_15', 'y_left_hand_16', 'y_left_hand_17', 'y_left_hand_18', 'y_left_hand_19', 'y_left_hand_20', 'z_left_hand_0', 'z_left_hand_1', 'z_left_hand_2', 'z_left_hand_3', 'z_left_hand_4', 'z_left_hand_5', 'z_left_hand_6', 'z_left_hand_7', 'z_left_hand_8', 'z_left_hand_9', 'z_left_hand_10', 'z_left_hand_11', 'z_left_hand_12', 'z_left_hand_13', 'z_left_hand_14', 'z_left_hand_15', 'z_left_hand_16', 'z_left_hand_17', 'z_left_hand_18', 'z_left_hand_19', 'z_left_hand_20',
 'z_pose_0', 'z_pose_1', 'z_pose_2', 'z_pose_3', 'z_pose_4', 'z_pose_5', 'z_pose_6', 'z_pose_7',
    'z_pose_8', 'z_pose_9', 'z_pose_10', 'z_pose_11', 'z_pose_12', 'z_pose_13', 'z_pose_14', 'z_pose_15',
    'z_pose_16', 'z_pose_17', 'z_pose_18', 'z_pose_19', 'z_pose_20', 'z_pose_21', 'z_pose_22', 'z_pose_23',
    'z_pose_24', 'z_pose_25', 'z_pose_26', 'z_pose_27', 'z_pose_28', 'z_pose_29', 'z_pose_30', 'z_pose_31',
    'z_pose_32']

table = pq.read_table('d:/Bureau/DS/aCapstone/527708222.parquet', columns=columns_of_interest)
df = table.to_pandas()
df.tail(20)
# Out:
#         frame  x_right_hand_0  x_right_hand_1  x_right_hand_2  x_right_hand_3  \
# 159717     74        0.299410        0.385437        0.438873        0.439802
# 159718     75        0.287708        0.385024        0.456364        0.470803
# 159719     76        0.288893        0.389368        0.450884        0.472833
# 159720     77        0.284880        0.389110        0.450857        0.472806
# 159721     78        0.289424        0.391996        0.453642        0.477309
# 159722     79        0.285055        0.380789        0.432917        0.432138
# 159723     80        0.283773        0.384572        0.445080        0.457283
# 159724     81        0.284949        0.386980        0.443748        0.453372
# 159725     82        0.286379        0.380391        0.429065        0.436931
# 159726     83             NaN             NaN             NaN             NaN
# 159727     84             NaN             NaN             NaN             NaN
# ...

# %% [markdown]
# I've made some test and verification, and observed that if there is ever a missing data for 'x_right_hand', than all right hand data is missing, and same for left hand. Therefore to simplify and speed the EDA on this part i will make a specific df 'tdf' for testdf to analyze further the position and patterns of missing data.

# %%
# Specify the number of rows you want to keep (in this case, 30,000)
num_rows_to_keep = 40107

# Use DataFrame slicing to select only the first 30,000 rows
ndf = df[:num_rows_to_keep]

# Now 'reduced_df' contains only the first 30,000 rows of the original DataFrame 'df'
print(ndf)
# Out:
#        frame  x_right_hand_0  x_right_hand_1  x_right_hand_2  x_right_hand_3  \
# 0          0        0.200624        0.302635        0.427209        0.531130
# 1          1        0.240830        0.374630        0.474594        0.547350
# 2          2        0.235014        0.375686        0.485869        0.566487
# 3          3        0.252615        0.385305        0.487498        0.563021
# 4          4        0.294039        0.405612        0.502041        0.568720
# ...      ...             ...             ...             ...             ...
# 40102    242        0.293540        0.380188        0.445382        0.480519
# 40103    243        0.324132        0.404965        0.470855        0.508212
# 40104    244        0.349544        0.429875        0.492972        0.527298
# 40105    245        0.363576        0.447008        0.505395        0.542994
# 40106    246        0.376617        0.467129        0.516210        0.557677
#
# ...

# %%
columns_of_interest = ['frame','x_right_hand_20' , 'z_left_hand_20']


table = pq.read_table('d:/Bureau/DS/aCapstone/527708222.parquet', columns=columns_of_interest)
tdf = table.to_pandas()
tdf.tail(60)
# Out:
#         frame  x_right_hand_20  z_left_hand_20
# 159677     34              NaN             NaN
# 159678     35              NaN             NaN
# 159679     36              NaN             NaN
# 159680     37         0.221298             NaN
# 159681     38         0.411067             NaN
# 159682     39         0.408853             NaN
# 159683     40         0.418892             NaN
# 159684     41         0.417278             NaN
# 159685     42         0.422621             NaN
# 159686     43         0.421051             NaN
# 159687     44         0.419860             NaN
# 159688     45         0.416441             NaN
# 159689     46         0.379241             NaN
# 159690     47              NaN             NaN
# 159691     48              NaN             NaN
# 159692     49              NaN             NaN
# 159693     50              NaN             NaN
# 159694     51         0.252497             NaN
# 159695     52         0.252037             NaN
# ...

# %% [markdown]
# Let's look at few hundreds of rows for right and left hand to have some understanding of the most common patterns.

# %%
# Assuming your DataFrame is named 'df'
rows = tdf.iloc[1050:1100]  # Note that the ending index is exclusive

rows
# Out:
#       frame  x_right_hand_20  z_left_hand_20
# 1050    239         0.429556             NaN
# 1051    240         0.432506             NaN
# 1052    241         0.435872             NaN
# 1053    242         0.439296             NaN
# 1054    243         0.439737             NaN
# 1055    244         0.438931             NaN
# 1056    245         0.446811             NaN
# 1057    246         0.452146             NaN
# 1058      0         0.263710             NaN
# 1059      1         0.256647             NaN
# 1060      2         0.255464             NaN
# 1061      3         0.260231             NaN
# 1062      4         0.282657             NaN
# 1063      5         0.302136             NaN
# 1064      6         0.314115             NaN
# 1065      7         0.273216             NaN
# 1066      8         0.307780             NaN
# 1067      9         0.272222             NaN
# 1068     10         0.260762             NaN
# 1069     11         0.230032             NaN
# ...

# %%
ndf.tail()
# Out:
#        frame  x_right_hand_0  x_right_hand_1  x_right_hand_2  x_right_hand_3  \
# 40102    242        0.293540        0.380188        0.445382        0.480519
# 40103    243        0.324132        0.404965        0.470855        0.508212
# 40104    244        0.349544        0.429875        0.492972        0.527298
# 40105    245        0.363576        0.447008        0.505395        0.542994
# 40106    246        0.376617        0.467129        0.516210        0.557677
#
#        x_right_hand_4  x_right_hand_5  x_right_hand_6  x_right_hand_7  \
# 40102        0.521557        0.387373        0.393184        0.442771
# 40103        0.557369        0.426497        0.430681        0.484099
# 40104        0.574678        0.456873        0.473039        0.526615
# 40105        0.594771        0.461990        0.487438        0.554616
# 40106        0.605394        0.450785        0.521018        0.597762
#
#        x_right_hand_8  ...  z_pose_23  z_pose_24  z_pose_25  z_pose_26  \
# ...

# %%
# Display information about the DataFrame
print(ndf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40107 entries, 0 to 40106
# Columns: 160 entries, frame to z_pose_32
# dtypes: float32(159), int16(1)
# memory usage: 24.4 MB
# None

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159737 entries, 0 to 159736
# Columns: 160 entries, frame to z_pose_32
# dtypes: float32(159), int16(1)
# memory usage: 97.2 MB
# None

# %%
# Replace 'path_to_file.parquet' with the actual file path on your system
file_path = 'd:/Bureau/DS/aCapstone/175396851.parquet'

# Open the Parquet file using ParquetFile
parquet_file = pq.ParquetFile(file_path)

# Define the row group index you want to read
# For example, to read the first row group, use index 0
row_group_index = 0

# Read the specific row group from the Parquet file
row_group_table = parquet_file.read_row_group(row_group_index)

# Convert the row group to a pandas DataFrame
df = row_group_table.to_pandas()

# Now you have a DataFrame with a part of the data from the Parquet file
df.head(100)
# Out:
#              frame  x_face_0  x_face_1  x_face_2  x_face_3  x_face_4  \
# sequence_id
# 99581249         0  0.697270  0.668842  0.677142  0.639997  0.664191
# 99581249         1  0.718483  0.671692  0.680300  0.642500  0.667015
# 99581249         2  0.677733  0.667229  0.676097  0.638806  0.662612
# 99581249         3  0.673708  0.670959  0.680167  0.641155  0.665971
# 99581249         4  0.659334  0.666794  0.676565  0.637701  0.661865
# ...            ...       ...       ...       ...       ...       ...
# 99581249        95  0.691976  0.668755  0.678227  0.639938  0.664453
# 99581249        96  0.687286  0.667383  0.677017  0.638586  0.663038
# 99581249        97  0.682651  0.664904  0.674323  0.637442  0.660853
# 99581249        98  0.680710  0.662987  0.672846  0.635490  0.658714
# 99581249        99  0.693802  0.678088  0.685359  0.650165  0.673833
#
#              x_face_5  x_face_6  x_face_7  x_face_8  x_face_9  x_face_10  \
# sequence_id
# ...

# %%
df['frame'].mean()
# Out:
# 100.52643407601245

# %%
df['frame'].describe()
# Out:
# count    159737.000000
# mean        100.526434
# std          77.515498
# min           0.000000
# 25%          41.000000
# 50%          84.000000
# 75%         142.000000
# max         477.000000
# Name: frame, dtype: float64

# %%
from pprint import pprint

# %%
# Get the names of all columns
all_column_names = ndf.columns.tolist()

# Use pprint to display the column names in a more readable way
pprint(all_column_names, compact=True)
# Out:
# ['frame', 'x_right_hand_0', 'x_right_hand_1', 'x_right_hand_2',
#  'x_right_hand_3', 'x_right_hand_4', 'x_right_hand_5', 'x_right_hand_6',
#  'x_right_hand_7', 'x_right_hand_8', 'x_right_hand_9', 'x_right_hand_10',
#  'x_right_hand_11', 'x_right_hand_12', 'x_right_hand_13', 'x_right_hand_14',
#  'x_right_hand_15', 'x_right_hand_16', 'x_right_hand_17', 'x_right_hand_18',
#  'x_right_hand_19', 'x_right_hand_20', 'y_right_hand_0', 'y_right_hand_1',
#  'y_right_hand_2', 'y_right_hand_3', 'y_right_hand_4', 'y_right_hand_5',
#  'y_right_hand_6', 'y_right_hand_7', 'y_right_hand_8', 'y_right_hand_9',
#  'y_right_hand_10', 'y_right_hand_11', 'y_right_hand_12', 'y_right_hand_13',
#  'y_right_hand_14', 'y_right_hand_15', 'y_right_hand_16', 'y_right_hand_17',
#  'y_right_hand_18', 'y_right_hand_19', 'y_right_hand_20', 'z_right_hand_0',
#  'z_right_hand_1', 'z_right_hand_2', 'z_right_hand_3', 'z_right_hand_4',
#  'z_right_hand_5', 'z_right_hand_6', 'z_right_hand_7', 'z_right_hand_8',
# ...

# %%
num_frame_zero = (df['frame'] == 0).sum()
print("Number of occurrences where 'frame' is equal to 0:", num_frame_zero)
# Out:
# Number of occurrences where 'frame' is equal to 0: 1000

# %%
num_frame_zero = (df['frame'] == 10).sum()
print("Number of occurrences where 'frame' is equal to 10:", num_frame_zero)
# Out:
# Number of occurrences where 'frame' is equal to 10: 969

# %%
all_column_names = ndf.columns.tolist()

# Save column names to a text file
with open('column_names.txt', 'w') as file:
    for column_name in all_column_names:
        file.write(column_name + '\n')

# %%
# Get the names of all columns
all_column_names = ndf.columns.tolist()

# Count the number of column names
num_columns = len(all_column_names)

# Display the number of columns
print("Number of columns:", num_columns)
# Out:
# Number of columns: 160

# %%
# Get the names of all columns
all_column_names = ndf.columns.tolist()

# Print all 1600 column names
print(all_column_names)
# Out:
# ['frame', 'x_right_hand_0', 'x_right_hand_1', 'x_right_hand_2', 'x_right_hand_3', 'x_right_hand_4', 'x_right_hand_5', 'x_right_hand_6', 'x_right_hand_7', 'x_right_hand_8', 'x_right_hand_9', 'x_right_hand_10', 'x_right_hand_11', 'x_right_hand_12', 'x_right_hand_13', 'x_right_hand_14', 'x_right_hand_15', 'x_right_hand_16', 'x_right_hand_17', 'x_right_hand_18', 'x_right_hand_19', 'x_right_hand_20', 'y_right_hand_0', 'y_right_hand_1', 'y_right_hand_2', 'y_right_hand_3', 'y_right_hand_4', 'y_right_hand_5', 'y_right_hand_6', 'y_right_hand_7', 'y_right_hand_8', 'y_right_hand_9', 'y_right_hand_10', 'y_right_hand_11', 'y_right_hand_12', 'y_right_hand_13', 'y_right_hand_14', 'y_right_hand_15', 'y_right_hand_16', 'y_right_hand_17', 'y_right_hand_18', 'y_right_hand_19', 'y_right_hand_20', 'z_right_hand_0', 'z_right_hand_1', 'z_right_hand_2', 'z_right_hand_3', 'z_right_hand_4', 'z_right_hand_5', 'z_right_hand_6', 'z_right_hand_7', 'z_right_hand_8', 'z_right_hand_9', 'z_right_hand_10', 'z_right_ha
# ...

# %%
df.infos()

# %%
file_path2 = 'd:/Bureau/DS/aCapstone/527708222.parquet'
# Open the Parquet file using ParquetFile
parquet_file2 = pq.ParquetFile(file_path2)

# Define the row group index you want to read
# For example, to read the first row group, use index 0
row_group_index2 = 0

# Read the specific row group from the Parquet file
row_group_table2 = parquet_file2.read_row_group(row_group_index2)

# Convert the row group to a pandas DataFrame
df2 = row_group_table2.to_pandas()

# Now you have a DataFrame with a part of the data from the Parquet file
df2.head(5)
# Out:
#              frame  x_face_0  x_face_1  x_face_2  x_face_3  x_face_4  \
# sequence_id
# 1880607618       0  0.487255  0.492607  0.494152  0.480811  0.492845
# 1880607618       1  0.488399  0.492968  0.494502  0.480484  0.493159
# 1880607618       2  0.491521  0.493348  0.495074  0.480274  0.493283
# 1880607618       3  0.486116  0.488677  0.490791  0.475851  0.488651
# 1880607618       4  0.492289  0.495260  0.498130  0.480569  0.494592
#
#              x_face_5  x_face_6  x_face_7  x_face_8  ...  z_right_hand_11  \
# sequence_id                                          ...
# 1880607618   0.494270  0.498394  0.368207  0.500288  ...        -0.196956
# 1880607618   0.494415  0.497935  0.367207  0.499401  ...        -0.171502
# 1880607618   0.494308  0.497388  0.367744  0.498564  ...        -0.154713
# 1880607618   0.489896  0.493834  0.366394  0.495337  ...        -0.173814
# 1880607618   0.494893  0.496912  0.366336  0.497359  ...        -0.117347
#
# ...

# %%
def has_video(parquet_file_path):
    try:
        # Read the Parquet file
        table = pq.read_table(parquet_file_path)

        # Get the first row of the table
        first_row = table[0]

        # Get the first column of the first row
        first_column = first_row[0]

        # Convert the PyArrow array to a NumPy array
        array = first_column.to_numpy()

        # Decode the data using OpenCV
        frame = cv2.imdecode(array, cv2.IMREAD_UNCHANGED)

        # Check if the decoded frame is not empty and is a video frame
        if frame is not None and len(frame.shape) == 3 and frame.shape[2] > 1:
            return True

    except Exception as e:
        # Handle any exceptions (e.g., file not found, invalid Parquet file, etc.)
        print("Error:", e)

    return False

# Example usage
parquet_file_path = "d:/Bureau/DS/aCapstone/175396851.parquet"
if has_video(parquet_file_path):
    print("The Parquet file contains video data.")
else:
    print("The Parquet file does not contain video data.")
# Out:
# Error: 'pyarrow.lib.Int16Scalar' object has no attribute 'to_numpy'
# The Parquet file does not contain video data.

# %%
num_frame_zero = (df2['frame'] == 0).sum()
print("Number of occurrences where 'frame' is equal to 0:", num_frame_zero)
# Out:
# Number of occurrences where 'frame' is equal to 0: 999

# %%
ndf['frame'].describe()
# Out:
# count    40107.000000
# mean        99.547261
# std         78.459755
# min          0.000000
# 25%         40.000000
# 50%         83.000000
# 75%        139.000000
# max        458.000000
# Name: frame, dtype: float64

# %%
# Count the occurrences of each unique value in the 'frame' column
frame_counts = ndf['frame'].value_counts()

# Check if there is a 0 frame in the DataFrame and get its count
count_of_zero_frame = frame_counts.get(0, 0)

# Print the count of 0 frame occurrences
print("Count of 0 frame occurrences:", count_of_zero_frame)
# Out:
# Count of 0 frame occurrences: 260

# %%
# Count the number of missing values in the 'x_left_hand_10' column
missing_x_left_hand_10_count = ndf['x_left_hand_10'].isna().sum()

# Print the count of rows where 'x_left_hand_10' has no value
print("Number of 'x_left_hand_10' with no value:", missing_x_left_hand_10_count)
# Out:
# Number of 'x_left_hand_10' with no value: 35270

# %%
# Count the number of missing values in the 'x_left_hand_10' column
missing_x_left_hand_10_count = ndf['x_right_hand_5'].isna().sum()

# Print the count of rows where 'x_left_hand_10' has no value
print("Number of 'x_left_hand_10' with no value:", missing_x_left_hand_10_count)
# Out:
# Number of 'x_left_hand_10' with no value: 21709

# %%
# Count the number of missing values in 'x_left_hand_10' and 'x_right_hand_10' columns
missing_x_left_hand_10_count = ndf['x_left_hand_10'].isna().sum()
missing_x_right_hand_10_count = ndf['x_right_hand_10'].isna().sum()

# Print the counts of rows where both 'x_left_hand_10' and 'x_right_hand_10' have no value
print("Number of 'x_left_hand_10' with no value:", missing_x_left_hand_10_count)
print("Number of 'x_right_hand_10' with no value:", missing_x_right_hand_10_count)
# Out:
# Number of 'x_left_hand_10' with no value: 35270
# Number of 'x_right_hand_10' with no value: 21709

# %%
is_x_left_hand_10_missing = ndf['x_left_hand_10'].isna()
is_x_right_hand_10_missing = ndf['x_right_hand_10'].isna()

# Combine the conditions using the logical OR operator
# This gives True for rows where either 'x_left_hand_10' or 'x_right_hand_10' has no value
rows_with_none_missing = is_x_left_hand_10_missing | is_x_right_hand_10_missing

# Count the number of rows where both 'x_left_hand_10' and 'x_right_hand_10' have no value
count_both_missing = rows_with_none_missing.sum()

# Print the count of rows where neither 'x_left_hand_10' nor 'x_right_hand_10' has a value
print("Number of rows with neither 'x_left_hand_10' nor 'x_right_hand_10' value:", count_both_missing)
# Out:
# Number of rows with neither 'x_left_hand_10' nor 'x_right_hand_10' value: 39683

# %%
# Check for missing values in 'x_left_hand_10' and 'x_right_hand_10' columns
is_x_left_hand_10_missing = ndf['x_left_hand_19'].isna()
is_x_right_hand_10_missing = ndf['x_right_hand_19'].isna()

# Combine the conditions using the logical AND operator
# This gives True for rows where both 'x_left_hand_10' and 'x_right_hand_10' have no value
rows_with_both_missing = is_x_left_hand_10_missing & is_x_right_hand_10_missing

# Count the number of rows where both 'x_left_hand_10' and 'x_right_hand_10' have no values
count_both_missing = rows_with_both_missing.sum()

# Print the count of rows where both 'x_left_hand_10' and 'x_right_hand_10' have no values
print("Number of rows with missing values for both 'x_left_hand_10' and 'x_right_hand_10':", count_both_missing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Check for missing values in 'x_left_hand_10' and 'x_right_hand_10' columns
# ----> 2 is_x_left_hand_10_missing = ndf['x_left_hand_19'].isna()
#       3 is_x_right_hand_10_missing = ndf['x_right_hand_19'].isna()
#       5 # Combine the conditions using the logical AND operator
#       6 # This gives True for rows where both 'x_left_hand_10' and 'x_right_hand_10' have no value
#
# NameError: name 'ndf' is not defined

# %% [markdown]
# Next step, understand better those no value, how distribuate are they per video.

# %% [markdown]
# ### Remove the n data that has no value in the interested hand for the last n row. ; Understand how i could clean those efficiently without loosing information

# %%
# Count the number of missing values in the 'x_left_hand_10' column
missing_x_left_hand_10_count = ndf['z_pose_9'].isna().sum()

# Print the count of rows where 'x_left_hand_10' has no value
print("Number of 'x_pose_5' with no value:", missing_x_left_hand_10_count)
# Out:
# Number of 'x_pose_5' with no value: 0
